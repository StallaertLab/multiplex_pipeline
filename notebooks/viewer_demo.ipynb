# %%
# %load_ext autoreload
# %autoreload 2

# %%
import spatialdata as sd
from napari_spatialdata import Interactive

# %%
sdata_path = r'R:\Wayne\BLCA\BLCA-1B_Analysis\temp\Core_006.zarr'

# %%
sdata = sd.read_zarr(sdata_path)
# Out:
# version mismatch: detected: RasterFormatV02, requested: FormatV04
# c:\Users\KMK280\AppData\Local\miniconda3\envs\sdata-env\Lib\site-packages\zarr\creation.py:610: UserWarning: ignoring keyword argument 'read_only'
#   compressor, fill_value = _kwargs_compat(compressor, fill_value, kwargs)
# version mismatch: detected: RasterFormatV02, requested: FormatV04
# version mismatch: detected: RasterFormatV02, requested: FormatV04
# version mismatch: detected: RasterFormatV02, requested: FormatV04
# version mismatch: detected: RasterFormatV02, requested: FormatV04
# version mismatch: detected: RasterFormatV02, requested: FormatV04
# version mismatch: detected: RasterFormatV02, requested: FormatV04
# version mismatch: detected: RasterFormatV02, requested: FormatV04
# version mismatch: detected: RasterFormatV02, requested: FormatV04
# version mismatch: detected: RasterFormatV02, requested: FormatV04
# version mismatch: detected: RasterFormatV02, requested: FormatV04
# ...

# %%
interactive = Interactive(sdata)
interactive.run()
# Out:
# c:\Users\KMK280\AppData\Local\miniconda3\envs\sdata-env\Lib\site-packages\anndata\_core\aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# 2025-07-02 16:42:59.535 | DEBUG    | napari_spatialdata._view:_on_layer_update:569 - Updating layer.
# 2025-07-02 16:42:59.537 | DEBUG    | napari_spatialdata._view:_on_layer_update:569 - Updating layer.
# c:\Users\KMK280\AppData\Local\miniconda3\envs\sdata-env\Lib\site-packages\anndata\_core\aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# 2025-07-02 16:43:37.674 | DEBUG    | napari_spatialdata._view:_on_layer_update:569 - Updating layer.
# 2025-07-02 16:43:37.682 | DEBUG    | napari_spatialdata._view:_on_layer_update:569 - Updating layer.
# 2025-07-02 16:43:37.685 | DEBUG    | napari_spatialdata._view:_on_layer_update:569 - Updating layer.
# ...
