# %%
# %load_ext autoreload
# %autoreload 2

from datetime import datetime
from pathlib import Path

import pandas as pd
from loguru import logger

from multiplex_pipeline.core_cutting.channel_scanner import discover_channels
from multiplex_pipeline.core_cutting.controller import CorePreparationController
from multiplex_pipeline.core_cutting.file_io import LocalFileStrategy
from multiplex_pipeline.utils.config_loaders import load_analysis_settings
# Out:
# c:\Users\KMK280\AppData\Local\miniconda3\envs\sdata-env\Lib\site-packages\dask\dataframe\__init__.py:31: FutureWarning: The legacy Dask DataFrame implementation is deprecated and will be removed in a future version. Set the configuration option `dataframe.query-planning` to `True` or None to enable the new Dask Dataframe implementation and silence this warning.
#   warnings.warn(
# c:\Users\KMK280\AppData\Local\miniconda3\envs\sdata-env\Lib\site-packages\xarray_schema\__init__.py:1: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import DistributionNotFound, get_distribution

# %% [markdown]
# ### Load analysis settings

# %%
# load analysis configuration
settings_path = r'C:\sdata_NRR-W\analysis_settings_NRR-W.yaml'

settings = load_analysis_settings(settings_path)
settings
# Out:
# AnalysisConfig(general=GeneralSettings(image_dir='R:/CellDive/NRR-W/NRR-W_Final', analysis_name='NRR-W_Analysis', local_analysis_dir='C:/sdata_NRR-W', remote_analysis_dir='/ix1/kkedziora', log_dir=None), core_detection=CoreDetectionSettings(detection_image='NRR-W_1.0.4_R000_DAPI__FINAL_F.ome.tif', core_info_file_path=None, im_level=6, min_area=2000, max_area=10000, min_iou=0.8, min_st=0.9, min_int=15, frame=4), core_cutting=CoreCuttingSettings(cores_dir_tif=None, cores_dir_output=None, include_channels=None, exclude_channels=None, use_markers=None, ignore_markers=['Antibody1'], margin=0, mask_value=0, transfer_cleanup_enabled=True, core_cleanup_enabled=True), additional_elements=[NormalizeStep(category='image_transformer', type='normalize', input='DAPI', output='DAPI_norm', keep=False, parameters=Params(low=1.0, high=99.8)), NormalizeStep(category='image_transformer', type='normalize', input='ECad', output='ECad_norm', keep=False, parameters=Params(low=1.0, high=99.8)), InstansegStep(category='object_segmenter', type='instanseg', input=['DAPI_norm', 'ECad_norm'], output=['instanseg_nucleus', 'instanseg_cell'], keep=True, parameters=Params(model='fluorescence_nuclei_and_cells', pixel_size=0.3, resolve_cell_and_nucleus=True, cleanup_fragments=True, clean_cache=True, normalise=False)), RingStep(category='mask_builder', type='ring', input=['instanseg_nucleus'], output='ring', keep=True, parameters=Params(outer=8, inner=2)), SubtractStep(category='mask_builder', type='subtract', input=['instanseg_cell', 'instanseg_nucleus'], output='cytoplasm', keep=True, parameters={})], qc=QcSettings(prefix='qc_exclude'), quant=[QuantTask(name='instanseg_table', masks={'nucleus': 'instanseg_nucleus', 'cell': 'instanseg_cell', 'ring': 'ring', 'cyto': 'cytoplasm'}, layer_connection='instanseg_cell')], sdata_storage=StorageSettings(chunk_size=[1, 512, 512], max_pyramid_level=3, downscale=2), analysis_dir=WindowsPath('C:/sdata_NRR-W/NRR-W_Analysis'), temp_dir=WindowsPath('C:/sdata_NRR-W/NRR-W_Analysis/temp'), log_dir_path=WindowsPath('C:/sdata_NRR-W/NRR-W_Analysis/logs'), core_info_file_path=WindowsPath('C:/sdata_NRR-W/NRR-W_Analysis/cores.csv'), cores_dir_tif_path=WindowsPath('C:/sdata_NRR-W/NRR-W_Analysis/temp'), cores_dir_output_path=WindowsPath('C:/sdata_NRR-W/NRR-W_Analysis/cores'))

# %% [markdown]
# ### Define the logger

# %%
log_file = settings.log_dir_path / f"cores_cutting_{datetime.now():%Y-%m-%d_%H-%M-%S}.log"

logger.remove()
l = logger.add(lambda msg: print(msg, end=""))
l = logger.add(log_file, level="DEBUG", enqueue=True)

# %% [markdown]
# ### Define cores for processing

# %%
df_path = settings.core_info_file_path.with_suffix('.pkl')

df = pd.read_pickle(df_path)
df.head()
# Out:
#   core_name  row_start  row_stop  column_start  column_stop poly_type  \
# 0  Core_000      192.0   40512.0       90176.0     132736.0   polygon
# 1  Core_001     1472.0   39232.0          64.0      26496.0   polygon
# 2  Core_002     1152.0   35584.0       37504.0      70720.0   polygon
#
#                                     polygon_vertices
# 0  [[7424.0, 94528.0], [5824.0, 98432.0], [3392.0...
# 1  [[9280.0, 8256.0], [6144.0, 11904.0], [2624.0,...
# 2  [[22656.0, 37952.0], [17024.0, 37504.0], [1299...

# %%
# # create a subset of cores (optional)
df = df[:1]
df
# Out:
#   core_name  row_start  row_stop  column_start  column_stop poly_type  \
# 0  Core_000      192.0   40512.0       90176.0     132736.0   polygon
#
#                                     polygon_vertices
# 0  [[7424.0, 94528.0], [5824.0, 98432.0], [3392.0...

# %% [markdown]
# ## Local files

# %%
channel_map = discover_channels(Path(settings.general.image_dir),
                                include_channels=settings.core_cutting.include_channels,
                                exclude_channels=settings.core_cutting.exclude_channels,
                                use_markers=settings.core_cutting.use_markers,
                                ignore_markers=settings.core_cutting.ignore_markers)
# Out:
# 2025-11-06 20:49:19.303 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:80 - Discovered 19 channels:
# 2025-11-06 20:49:19.305 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 001_AP2B <- R:\CellDive\NRR-W\NRR-W_Final\NRR-W_1.0.4_R000_Cy5_AP2B-AF647_FINAL_AFR_F.ome.tif
# 2025-11-06 20:49:19.305 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 001_DAPI <- R:\CellDive\NRR-W\NRR-W_Final\NRR-W_1.0.4_R000_DAPI__FINAL_F.ome.tif
# 2025-11-06 20:49:19.306 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 001_FOXA1 <- R:\CellDive\NRR-W\NRR-W_Final\NRR-W_1.0.4_R000_Cy3_FOXA1-AF555_FINAL_AFR_F.ome.tif
# 2025-11-06 20:49:19.307 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 002_DAPI <- R:\CellDive\NRR-W\NRR-W_Final\NRR-W_2.0.4_R000_DAPI__FINAL_F.ome.tif
# 2025-11-06 20:49:19.307 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 002_ER <- R:\CellDive\NRR-W\NRR-W_Final\NRR-W_2.0.4_R000_Cy3_ER-AF555_FINAL_AFR_F.ome.tif
# 2025-11-06 20:49:19.308 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 002_GATA3 <- R:\CellDive\NRR-W\NRR-W_Final\NRR-W_2.0.4_R000_Cy5_GATA3-AF647_FINAL_AFR_F.ome.tif
# 2025-11-06 20:49:19.308 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 003_AR <- R:\CellDive\NRR-W\NRR-W_Final\NRR-W_3.0.4_R000_Cy3_AR-AF555_FINAL_AFR_F.ome.tif
# 2025-11-06 20:49:19.310 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 003_DAPI <- R:\CellDive\NRR-W\NRR-W_Final\NRR-W_3.0.4_R000_DAPI__FINAL_F.ome.tif
# 2025-11-06 20:49:19.310 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 003_HER2 <- R:\CellDive\NRR-W\NRR-W_Final\NRR-W_3.0.4_R000_Cy5_HER2-AF647_FINAL_AFR_F.ome.tif
# 2025-11-06 20:49:19.311 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 004_AP2B <- R:\CellDive\NRR-W\NRR-W_Final\NRR-W_4.0.4_R000_Cy5_AP2B-AF647_FINAL_AFR_F.ome.tif
# 2025-11-06 20:49:19.312 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 004_DAPI <- R:\CellDive\NRR-W\NRR-W_Final\NRR-W_4.0.4_R000_DAPI__FINAL_F.ome.tif
# 2025-11-06 20:49:19.312 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 004_ECad <- R:\CellDive\NRR-W\NRR-W_Final\NRR-W_4.0.4_R000_Cy3_ECad-AF555_FINAL_AFR_F.ome.tif
# 2025-11-06 20:49:19.313 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 005_CD45 <- R:\CellDive\NRR-W\NRR-W_Final\NRR-W_5.0.4_R000_Cy5_CD45-AF647_FINAL_AFR_F.ome.tif
# 2025-11-06 20:49:19.314 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 005_CK818 <- R:\CellDive\NRR-W\NRR-W_Final\NRR-W_5.0.4_R000_Cy3_CK818-AF555_FINAL_AFR_F.ome.tif
# 2025-11-06 20:49:19.315 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 005_DAPI <- R:\CellDive\NRR-W\NRR-W_Final\NRR-W_5.0.4_R000_DAPI__FINAL_F.ome.tif
# 2025-11-06 20:49:19.316 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 005_ProgRc <- R:\CellDive\NRR-W\NRR-W_Final\NRR-W_5.0.4_R000_Cy7_ProgRc-AF750_FINAL_AFR_F.ome.tif
# 2025-11-06 20:49:19.317 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 006_CK14 <- R:\CellDive\NRR-W\NRR-W_Final\NRR-W_6.0.4_R000_Cy7_CK14-AF750_FINAL_AFR_F.ome.tif
# 2025-11-06 20:49:19.318 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 006_DAPI <- R:\CellDive\NRR-W\NRR-W_Final\NRR-W_6.0.4_R000_DAPI__FINAL_F.ome.tif
# 2025-11-06 20:49:19.318 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 006_SMA <- R:\CellDive\NRR-W\NRR-W_Final\NRR-W_6.0.4_R000_Cy3_SMA-Cy3_FINAL_AFR_F.ome.tif
# 2025-11-06 20:49:19.319 | WARNING  | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:127 - Requested ignore_marker 'Antibody1' not found.
# 2025-11-06 20:49:19.320 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:132 - Ignoring markers = ['Antibody1']
# 2025-11-06 20:49:19.321 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:133 - Final filtered channels: ['AP2B', 'DAPI', 'FOXA1', 'ER', 'GATA3', 'AR', 'HER2', 'ECad', 'CD45', 'CK818', 'ProgRc', 'CK14', 'SMA']
# 2025-11-06 20:49:19.322 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:139 - Final selected channels 13:
# 2025-11-06 20:49:19.323 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:141 -   Channel: AP2B <- R:\CellDive\NRR-W\NRR-W_Final\NRR-W_4.0.4_R000_Cy5_AP2B-AF647_FINAL_AFR_F.ome.tif
# 2025-11-06 20:49:19.324 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:141 -   Channel: AR <- R:\CellDive\NRR-W\NRR-W_Final\NRR-W_3.0.4_R000_Cy3_AR-AF555_FINAL_AFR_F.ome.tif
# 2025-11-06 20:49:19.324 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:141 -   Channel: CD45 <- R:\CellDive\NRR-W\NRR-W_Final\NRR-W_5.0.4_R000_Cy5_CD45-AF647_FINAL_AFR_F.ome.tif
# 2025-11-06 20:49:19.325 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:141 -   Channel: CK14 <- R:\CellDive\NRR-W\NRR-W_Final\NRR-W_6.0.4_R000_Cy7_CK14-AF750_FINAL_AFR_F.ome.tif
# 2025-11-06 20:49:19.326 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:141 -   Channel: CK818 <- R:\CellDive\NRR-W\NRR-W_Final\NRR-W_5.0.4_R000_Cy3_CK818-AF555_FINAL_AFR_F.ome.tif
# 2025-11-06 20:49:19.327 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:141 -   Channel: DAPI <- R:\CellDive\NRR-W\NRR-W_Final\NRR-W_1.0.4_R000_DAPI__FINAL_F.ome.tif
# 2025-11-06 20:49:19.328 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:141 -   Channel: ECad <- R:\CellDive\NRR-W\NRR-W_Final\NRR-W_4.0.4_R000_Cy3_ECad-AF555_FINAL_AFR_F.ome.tif
# 2025-11-06 20:49:19.328 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:141 -   Channel: ER <- R:\CellDive\NRR-W\NRR-W_Final\NRR-W_2.0.4_R000_Cy3_ER-AF555_FINAL_AFR_F.ome.tif
# 2025-11-06 20:49:19.330 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:141 -   Channel: FOXA1 <- R:\CellDive\NRR-W\NRR-W_Final\NRR-W_1.0.4_R000_Cy3_FOXA1-AF555_FINAL_AFR_F.ome.tif
# 2025-11-06 20:49:19.331 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:141 -   Channel: GATA3 <- R:\CellDive\NRR-W\NRR-W_Final\NRR-W_2.0.4_R000_Cy5_GATA3-AF647_FINAL_AFR_F.ome.tif
# 2025-11-06 20:49:19.332 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:141 -   Channel: HER2 <- R:\CellDive\NRR-W\NRR-W_Final\NRR-W_3.0.4_R000_Cy5_HER2-AF647_FINAL_AFR_F.ome.tif
# 2025-11-06 20:49:19.333 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:141 -   Channel: ProgRc <- R:\CellDive\NRR-W\NRR-W_Final\NRR-W_5.0.4_R000_Cy7_ProgRc-AF750_FINAL_AFR_F.ome.tif
# 2025-11-06 20:49:19.333 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:141 -   Channel: SMA <- R:\CellDive\NRR-W\NRR-W_Final\NRR-W_6.0.4_R000_Cy3_SMA-Cy3_FINAL_AFR_F.ome.tif
# 2025-11-06 20:49:19.334 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:143 - OME-TIFF files not used in final channel selection 6:
# 2025-11-06 20:49:19.335 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:145 -   Unused: Channel 001_AP2B <- R:\CellDive\NRR-W\NRR-W_Final\NRR-W_1.0.4_R000_Cy5_AP2B-AF647_FINAL_AFR_F.ome.tif
# 2025-11-06 20:49:19.336 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:145 -   Unused: Channel 002_DAPI <- R:\CellDive\NRR-W\NRR-W_Final\NRR-W_2.0.4_R000_DAPI__FINAL_F.ome.tif
# 2025-11-06 20:49:19.337 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:145 -   Unused: Channel 003_DAPI <- R:\CellDive\NRR-W\NRR-W_Final\NRR-W_3.0.4_R000_DAPI__FINAL_F.ome.tif
# 2025-11-06 20:49:19.337 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:145 -   Unused: Channel 004_DAPI <- R:\CellDive\NRR-W\NRR-W_Final\NRR-W_4.0.4_R000_DAPI__FINAL_F.ome.tif
# 2025-11-06 20:49:19.338 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:145 -   Unused: Channel 005_DAPI <- R:\CellDive\NRR-W\NRR-W_Final\NRR-W_5.0.4_R000_DAPI__FINAL_F.ome.tif
# 2025-11-06 20:49:19.339 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:145 -   Unused: Channel 006_DAPI <- R:\CellDive\NRR-W\NRR-W_Final\NRR-W_6.0.4_R000_DAPI__FINAL_F.ome.tif

# %%
# # for tests you can request a small set of channels here
# # then send 'short_map' to the controller instead of 'channel_map'
# selected_keys = ["DAPI", "CD3"]
# short_map = {k: channel_map[k] for k in selected_keys if k in channel_map}
# short_map
# Out:
# {'DAPI': 'R:\\CellDive\\BLCA-1B\\BLCA-1B_Final\\BLCA-1B_1.0.4_R000_DAPI__FINAL_F.ome.tif',
#  'CD3': 'R:\\CellDive\\BLCA-1B\\BLCA-1B_Final\\BLCA-1B_11.0.4_R000_Cy3_CD3-AF555_FINAL_AFR_F.ome.tif'}

# %%
strategy = LocalFileStrategy()

controller = CorePreparationController(
    metadata_df = df, # df defines which cores to process
    image_paths = channel_map, # defines which channels to use
    temp_dir = settings.cores_dir_tif_path,
    output_dir = settings.cores_dir_output_path,
    file_strategy = strategy,
    margin = settings.core_cutting.margin,
    mask_value = settings.core_cutting.mask_value,
    max_pyramid_levels = settings.sdata_storage.max_pyramid_level,
    chunk_size = settings.sdata_storage.chunk_size,
    downscale = settings.sdata_storage.chunk_size,
    )


controller.run()
# Out:
# 2025-11-06 20:49:23.709 | INFO     | multiplex_pipeline.core_cutting.controller:run:117 - Starting controller run loop...
# 2025-11-06 20:49:23.714 | INFO     | multiplex_pipeline.core_cutting.controller:run:127 - Channel AP2B file available at R:\CellDive\NRR-W\NRR-W_Final\NRR-W_4.0.4_R000_Cy5_AP2B-AF647_FINAL_AFR_F.ome.tif.
# 2025-11-06 20:50:50.253 | DEBUG    | multiplex_pipeline.core_cutting.controller:cut_channel:93 - Cut and saved core Core_000, channel AP2B.
# 2025-11-06 20:52:21.032 | DEBUG    | multiplex_pipeline.core_cutting.controller:cut_channel:93 - Cut and saved core Core_001, channel AP2B.
# 2025-11-06 20:54:43.638 | DEBUG    | multiplex_pipeline.core_cutting.controller:cut_channel:93 - Cut and saved core Core_002, channel AP2B.
# 2025-11-06 20:54:44.459 | DEBUG    | multiplex_pipeline.core_cutting.controller:cut_channel:100 - Closed file handle for channel AP2B.
# 2025-11-06 20:54:44.824 | INFO     | multiplex_pipeline.core_cutting.controller:run:127 - Channel DAPI file available at R:\CellDive\NRR-W\NRR-W_Final\NRR-W_1.0.4_R000_DAPI__FINAL_F.ome.tif.
# 2025-11-06 20:56:01.539 | DEBUG    | multiplex_pipeline.core_cutting.controller:cut_channel:93 - Cut and saved core Core_000, channel DAPI.
# 2025-11-06 20:57:38.582 | DEBUG    | multiplex_pipeline.core_cutting.controller:cut_channel:93 - Cut and saved core Core_001, channel DAPI.
# 2025-11-06 20:59:50.055 | DEBUG    | multiplex_pipeline.core_cutting.controller:cut_channel:93 - Cut and saved core Core_002, channel DAPI.
# 2025-11-06 20:59:50.698 | DEBUG    | multiplex_pipeline.core_cutting.controller:cut_channel:100 - Closed file handle for channel DAPI.
# 2025-11-06 20:59:51.026 | INFO     | multiplex_pipeline.core_cutting.controller:run:127 - Channel FOXA1 file available at R:\CellDive\NRR-W\NRR-W_Final\NRR-W_1.0.4_R000_Cy3_FOXA1-AF555_FINAL_AFR_F.ome.tif.
# 2025-11-06 21:01:13.969 | DEBUG    | multiplex_pipeline.core_cutting.controller:cut_channel:93 - Cut and saved core Core_000, channel FOXA1.
# 2025-11-06 21:02:05.580 | DEBUG    | multiplex_pipeline.core_cutting.controller:cut_channel:93 - Cut and saved core Core_001, channel FOXA1.
# 2025-11-06 21:03:13.225 | DEBUG    | multiplex_pipeline.core_cutting.controller:cut_channel:93 - Cut and saved core Core_002, channel FOXA1.
# 2025-11-06 21:03:14.010 | DEBUG    | multiplex_pipeline.core_cutting.controller:cut_channel:100 - Closed file handle for channel FOXA1.
# 2025-11-06 21:03:14.395 | INFO     | multiplex_pipeline.core_cutting.controller:run:127 - Channel ER file available at R:\CellDive\NRR-W\NRR-W_Final\NRR-W_2.0.4_R000_Cy3_ER-AF555_FINAL_AFR_F.ome.tif.
# 2025-11-06 21:04:50.154 | DEBUG    | multiplex_pipeline.core_cutting.controller:cut_channel:93 - Cut and saved core Core_000, channel ER.
# 2025-11-06 21:05:41.446 | DEBUG    | multiplex_pipeline.core_cutting.controller:cut_channel:93 - Cut and saved core Core_001, channel ER.
# 2025-11-06 21:06:45.613 | DEBUG    | multiplex_pipeline.core_cutting.controller:cut_channel:93 - Cut and saved core Core_002, channel ER.
# 2025-11-06 21:06:46.274 | DEBUG    | multiplex_pipeline.core_cutting.controller:cut_channel:100 - Closed file handle for channel ER.
# 2025-11-06 21:06:46.619 | INFO     | multiplex_pipeline.core_cutting.controller:run:127 - Channel GATA3 file available at R:\CellDive\NRR-W\NRR-W_Final\NRR-W_2.0.4_R000_Cy5_GATA3-AF647_FINAL_AFR_F.ome.tif.
# 2025-11-06 21:08:23.203 | DEBUG    | multiplex_pipeline.core_cutting.controller:cut_channel:93 - Cut and saved core Core_000, channel GATA3.
# 2025-11-06 21:09:13.318 | DEBUG    | multiplex_pipeline.core_cutting.controller:cut_channel:93 - Cut and saved core Core_001, channel GATA3.
# 2025-11-06 21:10:18.251 | DEBUG    | multiplex_pipeline.core_cutting.controller:cut_channel:93 - Cut and saved core Core_002, channel GATA3.
# 2025-11-06 21:10:19.014 | DEBUG    | multiplex_pipeline.core_cutting.controller:cut_channel:100 - Closed file handle for channel GATA3.
# 2025-11-06 21:10:19.355 | INFO     | multiplex_pipeline.core_cutting.controller:run:127 - Channel AR file available at R:\CellDive\NRR-W\NRR-W_Final\NRR-W_3.0.4_R000_Cy3_AR-AF555_FINAL_AFR_F.ome.tif.
# 2025-11-06 21:11:51.758 | DEBUG    | multiplex_pipeline.core_cutting.controller:cut_channel:93 - Cut and saved core Core_000, channel AR.
# 2025-11-06 21:12:42.120 | DEBUG    | multiplex_pipeline.core_cutting.controller:cut_channel:93 - Cut and saved core Core_001, channel AR.
# 2025-11-06 21:13:48.014 | DEBUG    | multiplex_pipeline.core_cutting.controller:cut_channel:93 - Cut and saved core Core_002, channel AR.
# 2025-11-06 21:13:48.979 | DEBUG    | multiplex_pipeline.core_cutting.controller:cut_channel:100 - Closed file handle for channel AR.
# 2025-11-06 21:13:49.301 | INFO     | multiplex_pipeline.core_cutting.controller:run:127 - Channel HER2 file available at R:\CellDive\NRR-W\NRR-W_Final\NRR-W_3.0.4_R000_Cy5_HER2-AF647_FINAL_AFR_F.ome.tif.
# 2025-11-06 21:15:28.176 | DEBUG    | multiplex_pipeline.core_cutting.controller:cut_channel:93 - Cut and saved core Core_000, channel HER2.
# 2025-11-06 21:16:18.244 | DEBUG    | multiplex_pipeline.core_cutting.controller:cut_channel:93 - Cut and saved core Core_001, channel HER2.
# 2025-11-06 21:17:23.702 | DEBUG    | multiplex_pipeline.core_cutting.controller:cut_channel:93 - Cut and saved core Core_002, channel HER2.
# 2025-11-06 21:17:24.616 | DEBUG    | multiplex_pipeline.core_cutting.controller:cut_channel:100 - Closed file handle for channel HER2.
# 2025-11-06 21:17:25.001 | INFO     | multiplex_pipeline.core_cutting.controller:run:127 - Channel ECad file available at R:\CellDive\NRR-W\NRR-W_Final\NRR-W_4.0.4_R000_Cy3_ECad-AF555_FINAL_AFR_F.ome.tif.
# 2025-11-06 21:18:57.897 | DEBUG    | multiplex_pipeline.core_cutting.controller:cut_channel:93 - Cut and saved core Core_000, channel ECad.
# 2025-11-06 21:20:33.800 | DEBUG    | multiplex_pipeline.core_cutting.controller:cut_channel:93 - Cut and saved core Core_001, channel ECad.
# 2025-11-06 21:22:54.877 | DEBUG    | multiplex_pipeline.core_cutting.controller:cut_channel:93 - Cut and saved core Core_002, channel ECad.
# 2025-11-06 21:22:55.530 | DEBUG    | multiplex_pipeline.core_cutting.controller:cut_channel:100 - Closed file handle for channel ECad.
# 2025-11-06 21:22:55.860 | INFO     | multiplex_pipeline.core_cutting.controller:run:127 - Channel CD45 file available at R:\CellDive\NRR-W\NRR-W_Final\NRR-W_5.0.4_R000_Cy5_CD45-AF647_FINAL_AFR_F.ome.tif.
# 2025-11-06 21:24:37.022 | DEBUG    | multiplex_pipeline.core_cutting.controller:cut_channel:93 - Cut and saved core Core_000, channel CD45.
# 2025-11-06 21:25:30.279 | DEBUG    | multiplex_pipeline.core_cutting.controller:cut_channel:93 - Cut and saved core Core_001, channel CD45.
# 2025-11-06 21:26:37.558 | DEBUG    | multiplex_pipeline.core_cutting.controller:cut_channel:93 - Cut and saved core Core_002, channel CD45.
# 2025-11-06 21:26:38.246 | DEBUG    | multiplex_pipeline.core_cutting.controller:cut_channel:100 - Closed file handle for channel CD45.
# 2025-11-06 21:26:38.547 | INFO     | multiplex_pipeline.core_cutting.controller:run:127 - Channel CK818 file available at R:\CellDive\NRR-W\NRR-W_Final\NRR-W_5.0.4_R000_Cy3_CK818-AF555_FINAL_AFR_F.ome.tif.
# 2025-11-06 21:28:16.160 | DEBUG    | multiplex_pipeline.core_cutting.controller:cut_channel:93 - Cut and saved core Core_000, channel CK818.
# 2025-11-06 21:29:08.626 | DEBUG    | multiplex_pipeline.core_cutting.controller:cut_channel:93 - Cut and saved core Core_001, channel CK818.
# 2025-11-06 21:30:10.446 | DEBUG    | multiplex_pipeline.core_cutting.controller:cut_channel:93 - Cut and saved core Core_002, channel CK818.
# 2025-11-06 21:30:11.098 | DEBUG    | multiplex_pipeline.core_cutting.controller:cut_channel:100 - Closed file handle for channel CK818.
# 2025-11-06 21:30:11.424 | INFO     | multiplex_pipeline.core_cutting.controller:run:127 - Channel ProgRc file available at R:\CellDive\NRR-W\NRR-W_Final\NRR-W_5.0.4_R000_Cy7_ProgRc-AF750_FINAL_AFR_F.ome.tif.
# 2025-11-06 21:31:49.355 | DEBUG    | multiplex_pipeline.core_cutting.controller:cut_channel:93 - Cut and saved core Core_000, channel ProgRc.
# 2025-11-06 21:33:35.648 | DEBUG    | multiplex_pipeline.core_cutting.controller:cut_channel:93 - Cut and saved core Core_001, channel ProgRc.
# 2025-11-06 21:36:15.364 | DEBUG    | multiplex_pipeline.core_cutting.controller:cut_channel:93 - Cut and saved core Core_002, channel ProgRc.
# 2025-11-06 21:36:16.387 | DEBUG    | multiplex_pipeline.core_cutting.controller:cut_channel:100 - Closed file handle for channel ProgRc.
# 2025-11-06 21:36:16.862 | INFO     | multiplex_pipeline.core_cutting.controller:run:127 - Channel CK14 file available at R:\CellDive\NRR-W\NRR-W_Final\NRR-W_6.0.4_R000_Cy7_CK14-AF750_FINAL_AFR_F.ome.tif.
# 2025-11-06 21:38:01.261 | DEBUG    | multiplex_pipeline.core_cutting.controller:cut_channel:93 - Cut and saved core Core_000, channel CK14.
# 2025-11-06 21:38:56.131 | DEBUG    | multiplex_pipeline.core_cutting.controller:cut_channel:93 - Cut and saved core Core_001, channel CK14.
# 2025-11-06 21:40:05.728 | DEBUG    | multiplex_pipeline.core_cutting.controller:cut_channel:93 - Cut and saved core Core_002, channel CK14.
# 2025-11-06 21:40:06.736 | DEBUG    | multiplex_pipeline.core_cutting.controller:cut_channel:100 - Closed file handle for channel CK14.
# 2025-11-06 21:40:07.107 | INFO     | multiplex_pipeline.core_cutting.controller:run:127 - Channel SMA file available at R:\CellDive\NRR-W\NRR-W_Final\NRR-W_6.0.4_R000_Cy3_SMA-Cy3_FINAL_AFR_F.ome.tif.
# 2025-11-06 21:41:46.280 | DEBUG    | multiplex_pipeline.core_cutting.controller:cut_channel:93 - Cut and saved core Core_000, channel SMA.
# 2025-11-06 21:42:38.512 | DEBUG    | multiplex_pipeline.core_cutting.controller:cut_channel:93 - Cut and saved core Core_001, channel SMA.
# 2025-11-06 21:43:45.205 | DEBUG    | multiplex_pipeline.core_cutting.controller:cut_channel:93 - Cut and saved core Core_002, channel SMA.
# 2025-11-06 21:43:45.896 | DEBUG    | multiplex_pipeline.core_cutting.controller:cut_channel:100 - Closed file handle for channel SMA.
# 2025-11-06 21:43:46.198 | INFO     | multiplex_pipeline.core_cutting.controller:try_assemble_ready_cores:106 - Assembling full core Core_000
# INFO     The Zarr backing store has been changed from None the new file path:
#          C:\sdata_NRR-W\NRR-W_Analysis\cores\Core_000.zarr
# 2025-11-06 21:56:18.387 | INFO     | multiplex_pipeline.core_cutting.assembler:assemble_core:113 - Core 'Core_000' assembled with channels: ['AP2B', 'AR', 'CD45', 'CK14', 'CK818', 'DAPI', 'ECad', 'ER', 'FOXA1', 'GATA3', 'HER2', 'ProgRc', 'SMA']
# 2025-11-06 21:56:18.393 | DEBUG    | multiplex_pipeline.core_cutting.assembler:_cleanup_core_files:131 - Deleted intermediate TIFF: C:\sdata_NRR-W\NRR-W_Analysis\temp\Core_000\AP2B.tiff
# 2025-11-06 21:56:18.401 | DEBUG    | multiplex_pipeline.core_cutting.assembler:_cleanup_core_files:131 - Deleted intermediate TIFF: C:\sdata_NRR-W\NRR-W_Analysis\temp\Core_000\AR.tiff
# 2025-11-06 21:56:18.403 | DEBUG    | multiplex_pipeline.core_cutting.assembler:_cleanup_core_files:131 - Deleted intermediate TIFF: C:\sdata_NRR-W\NRR-W_Analysis\temp\Core_000\CD45.tiff
# 2025-11-06 21:56:18.405 | DEBUG    | multiplex_pipeline.core_cutting.assembler:_cleanup_core_files:131 - Deleted intermediate TIFF: C:\sdata_NRR-W\NRR-W_Analysis\temp\Core_000\CK14.tiff
# 2025-11-06 21:56:18.431 | DEBUG    | multiplex_pipeline.core_cutting.assembler:_cleanup_core_files:131 - Deleted intermediate TIFF: C:\sdata_NRR-W\NRR-W_Analysis\temp\Core_000\CK818.tiff
# 2025-11-06 21:56:19.026 | DEBUG    | multiplex_pipeline.core_cutting.assembler:_cleanup_core_files:131 - Deleted intermediate TIFF: C:\sdata_NRR-W\NRR-W_Analysis\temp\Core_000\DAPI.tiff
# 2025-11-06 21:56:19.646 | DEBUG    | multiplex_pipeline.core_cutting.assembler:_cleanup_core_files:131 - Deleted intermediate TIFF: C:\sdata_NRR-W\NRR-W_Analysis\temp\Core_000\ECad.tiff
# 2025-11-06 21:56:20.253 | DEBUG    | multiplex_pipeline.core_cutting.assembler:_cleanup_core_files:131 - Deleted intermediate TIFF: C:\sdata_NRR-W\NRR-W_Analysis\temp\Core_000\ER.tiff
# 2025-11-06 21:56:20.872 | DEBUG    | multiplex_pipeline.core_cutting.assembler:_cleanup_core_files:131 - Deleted intermediate TIFF: C:\sdata_NRR-W\NRR-W_Analysis\temp\Core_000\FOXA1.tiff
# 2025-11-06 21:56:21.496 | DEBUG    | multiplex_pipeline.core_cutting.assembler:_cleanup_core_files:131 - Deleted intermediate TIFF: C:\sdata_NRR-W\NRR-W_Analysis\temp\Core_000\GATA3.tiff
# 2025-11-06 21:56:22.082 | DEBUG    | multiplex_pipeline.core_cutting.assembler:_cleanup_core_files:131 - Deleted intermediate TIFF: C:\sdata_NRR-W\NRR-W_Analysis\temp\Core_000\HER2.tiff
# 2025-11-06 21:56:22.758 | DEBUG    | multiplex_pipeline.core_cutting.assembler:_cleanup_core_files:131 - Deleted intermediate TIFF: C:\sdata_NRR-W\NRR-W_Analysis\temp\Core_000\ProgRc.tiff
# 2025-11-06 21:56:23.378 | DEBUG    | multiplex_pipeline.core_cutting.assembler:_cleanup_core_files:131 - Deleted intermediate TIFF: C:\sdata_NRR-W\NRR-W_Analysis\temp\Core_000\SMA.tiff
# 2025-11-06 21:56:23.378 | INFO     | multiplex_pipeline.core_cutting.controller:try_assemble_ready_cores:106 - Assembling full core Core_001
# INFO     The Zarr backing store has been changed from None the new file path:
#          C:\sdata_NRR-W\NRR-W_Analysis\cores\Core_001.zarr
# 2025-11-06 22:03:29.328 | INFO     | multiplex_pipeline.core_cutting.assembler:assemble_core:113 - Core 'Core_001' assembled with channels: ['AP2B', 'AR', 'CD45', 'CK14', 'CK818', 'DAPI', 'ECad', 'ER', 'FOXA1', 'GATA3', 'HER2', 'ProgRc', 'SMA']
# 2025-11-06 22:03:29.663 | DEBUG    | multiplex_pipeline.core_cutting.assembler:_cleanup_core_files:131 - Deleted intermediate TIFF: C:\sdata_NRR-W\NRR-W_Analysis\temp\Core_001\AP2B.tiff
# 2025-11-06 22:03:29.995 | DEBUG    | multiplex_pipeline.core_cutting.assembler:_cleanup_core_files:131 - Deleted intermediate TIFF: C:\sdata_NRR-W\NRR-W_Analysis\temp\Core_001\AR.tiff
# 2025-11-06 22:03:30.276 | DEBUG    | multiplex_pipeline.core_cutting.assembler:_cleanup_core_files:131 - Deleted intermediate TIFF: C:\sdata_NRR-W\NRR-W_Analysis\temp\Core_001\CD45.tiff
# 2025-11-06 22:03:30.560 | DEBUG    | multiplex_pipeline.core_cutting.assembler:_cleanup_core_files:131 - Deleted intermediate TIFF: C:\sdata_NRR-W\NRR-W_Analysis\temp\Core_001\CK14.tiff
# 2025-11-06 22:03:30.806 | DEBUG    | multiplex_pipeline.core_cutting.assembler:_cleanup_core_files:131 - Deleted intermediate TIFF: C:\sdata_NRR-W\NRR-W_Analysis\temp\Core_001\CK818.tiff
# 2025-11-06 22:03:31.038 | DEBUG    | multiplex_pipeline.core_cutting.assembler:_cleanup_core_files:131 - Deleted intermediate TIFF: C:\sdata_NRR-W\NRR-W_Analysis\temp\Core_001\DAPI.tiff
# 2025-11-06 22:03:31.400 | DEBUG    | multiplex_pipeline.core_cutting.assembler:_cleanup_core_files:131 - Deleted intermediate TIFF: C:\sdata_NRR-W\NRR-W_Analysis\temp\Core_001\ECad.tiff
# 2025-11-06 22:03:31.665 | DEBUG    | multiplex_pipeline.core_cutting.assembler:_cleanup_core_files:131 - Deleted intermediate TIFF: C:\sdata_NRR-W\NRR-W_Analysis\temp\Core_001\ER.tiff
# 2025-11-06 22:03:31.982 | DEBUG    | multiplex_pipeline.core_cutting.assembler:_cleanup_core_files:131 - Deleted intermediate TIFF: C:\sdata_NRR-W\NRR-W_Analysis\temp\Core_001\FOXA1.tiff
# 2025-11-06 22:03:32.271 | DEBUG    | multiplex_pipeline.core_cutting.assembler:_cleanup_core_files:131 - Deleted intermediate TIFF: C:\sdata_NRR-W\NRR-W_Analysis\temp\Core_001\GATA3.tiff
# 2025-11-06 22:03:32.627 | DEBUG    | multiplex_pipeline.core_cutting.assembler:_cleanup_core_files:131 - Deleted intermediate TIFF: C:\sdata_NRR-W\NRR-W_Analysis\temp\Core_001\HER2.tiff
# 2025-11-06 22:03:33.007 | DEBUG    | multiplex_pipeline.core_cutting.assembler:_cleanup_core_files:131 - Deleted intermediate TIFF: C:\sdata_NRR-W\NRR-W_Analysis\temp\Core_001\ProgRc.tiff
# 2025-11-06 22:03:33.378 | DEBUG    | multiplex_pipeline.core_cutting.assembler:_cleanup_core_files:131 - Deleted intermediate TIFF: C:\sdata_NRR-W\NRR-W_Analysis\temp\Core_001\SMA.tiff
# 2025-11-06 22:03:33.380 | INFO     | multiplex_pipeline.core_cutting.controller:try_assemble_ready_cores:106 - Assembling full core Core_002
# INFO     The Zarr backing store has been changed from None the new file path:
#          C:\sdata_NRR-W\NRR-W_Analysis\cores\Core_002.zarr
# 2025-11-06 22:12:47.166 | INFO     | multiplex_pipeline.core_cutting.assembler:assemble_core:113 - Core 'Core_002' assembled with channels: ['AP2B', 'AR', 'CD45', 'CK14', 'CK818', 'DAPI', 'ECad', 'ER', 'FOXA1', 'GATA3', 'HER2', 'ProgRc', 'SMA']
# 2025-11-06 22:12:47.752 | DEBUG    | multiplex_pipeline.core_cutting.assembler:_cleanup_core_files:131 - Deleted intermediate TIFF: C:\sdata_NRR-W\NRR-W_Analysis\temp\Core_002\AP2B.tiff
# 2025-11-06 22:12:48.174 | DEBUG    | multiplex_pipeline.core_cutting.assembler:_cleanup_core_files:131 - Deleted intermediate TIFF: C:\sdata_NRR-W\NRR-W_Analysis\temp\Core_002\AR.tiff
# 2025-11-06 22:12:48.720 | DEBUG    | multiplex_pipeline.core_cutting.assembler:_cleanup_core_files:131 - Deleted intermediate TIFF: C:\sdata_NRR-W\NRR-W_Analysis\temp\Core_002\CD45.tiff
# 2025-11-06 22:12:49.068 | DEBUG    | multiplex_pipeline.core_cutting.assembler:_cleanup_core_files:131 - Deleted intermediate TIFF: C:\sdata_NRR-W\NRR-W_Analysis\temp\Core_002\CK14.tiff
# 2025-11-06 22:12:49.332 | DEBUG    | multiplex_pipeline.core_cutting.assembler:_cleanup_core_files:131 - Deleted intermediate TIFF: C:\sdata_NRR-W\NRR-W_Analysis\temp\Core_002\CK818.tiff
# 2025-11-06 22:12:49.781 | DEBUG    | multiplex_pipeline.core_cutting.assembler:_cleanup_core_files:131 - Deleted intermediate TIFF: C:\sdata_NRR-W\NRR-W_Analysis\temp\Core_002\DAPI.tiff
# 2025-11-06 22:12:50.143 | DEBUG    | multiplex_pipeline.core_cutting.assembler:_cleanup_core_files:131 - Deleted intermediate TIFF: C:\sdata_NRR-W\NRR-W_Analysis\temp\Core_002\ECad.tiff
# 2025-11-06 22:12:50.498 | DEBUG    | multiplex_pipeline.core_cutting.assembler:_cleanup_core_files:131 - Deleted intermediate TIFF: C:\sdata_NRR-W\NRR-W_Analysis\temp\Core_002\ER.tiff
# 2025-11-06 22:12:50.998 | DEBUG    | multiplex_pipeline.core_cutting.assembler:_cleanup_core_files:131 - Deleted intermediate TIFF: C:\sdata_NRR-W\NRR-W_Analysis\temp\Core_002\FOXA1.tiff
# 2025-11-06 22:12:51.420 | DEBUG    | multiplex_pipeline.core_cutting.assembler:_cleanup_core_files:131 - Deleted intermediate TIFF: C:\sdata_NRR-W\NRR-W_Analysis\temp\Core_002\GATA3.tiff
# 2025-11-06 22:12:51.748 | DEBUG    | multiplex_pipeline.core_cutting.assembler:_cleanup_core_files:131 - Deleted intermediate TIFF: C:\sdata_NRR-W\NRR-W_Analysis\temp\Core_002\HER2.tiff
# 2025-11-06 22:12:52.131 | DEBUG    | multiplex_pipeline.core_cutting.assembler:_cleanup_core_files:131 - Deleted intermediate TIFF: C:\sdata_NRR-W\NRR-W_Analysis\temp\Core_002\ProgRc.tiff
# 2025-11-06 22:12:52.600 | DEBUG    | multiplex_pipeline.core_cutting.assembler:_cleanup_core_files:131 - Deleted intermediate TIFF: C:\sdata_NRR-W\NRR-W_Analysis\temp\Core_002\SMA.tiff
# 2025-11-06 22:12:52.600 | INFO     | multiplex_pipeline.core_cutting.controller:run:137 - All channels processed and cores assembled.
