# %%
# %load_ext autoreload
# %autoreload 2

from datetime import datetime
from pathlib import Path

import pandas as pd
from loguru import logger

from multiplex_pipeline.core_cutting.channel_scanner import discover_channels
from multiplex_pipeline.core_cutting.controller import CorePreparationController
from multiplex_pipeline.core_cutting.file_io import LocalFileStrategy
from multiplex_pipeline.utils.config_loaders import load_analysis_settings
# Out:
# c:\Users\KMK280\AppData\Local\miniconda3\envs\sdata-env\Lib\site-packages\dask\dataframe\__init__.py:31: FutureWarning: The legacy Dask DataFrame implementation is deprecated and will be removed in a future version. Set the configuration option `dataframe.query-planning` to `True` or None to enable the new Dask Dataframe implementation and silence this warning.
#   warnings.warn(
# c:\Users\KMK280\AppData\Local\miniconda3\envs\sdata-env\Lib\site-packages\xarray_schema\__init__.py:1: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import DistributionNotFound, get_distribution

# %% [markdown]
# ### Load analysis settings

# %%
# load analysis configuration
settings_path = r'C:\BLCA-7_Analysis\analysis_settings_BLCA7.yaml'

settings = load_analysis_settings(settings_path)
settings
# Out:
# AnalysisConfig(general=GeneralSettings(image_dir='R:/CellDive/BLCA-7/BLCA-7_Final', analysis_name='BLCA-7_Analysis', local_analysis_dir='C:/', remote_analysis_dir='/ix1/kkedziora/blca_analysis', log_dir=None), core_detection=CoreDetectionSettings(detection_image='BLCA-7_1.0.4_R000_DAPI__FINAL_F.ome.tif', core_info_file_path=None, im_level=6, min_area=2000, max_area=10000, min_iou=0.8, min_st=0.9, min_int=15, frame=4), core_cutting=CoreCuttingSettings(cores_dir_tif=None, cores_dir_output=None, include_channels=None, exclude_channels=['008_ECad'], use_markers=['DAPI', 'CD45', 'CD44', 'HLA1', 'CD44', 'NaKATPase', 'CD11C', 'pCK26', 'pS6', 'HES1'], ignore_markers=['Antibody1', 'TNFa', 'Snail1', 'SKP2', 'ProgRc', 'Plk1', 'PH3', 'PDL1', 'p65', 'p130', 'p-p130', 'p-Cdc6', 'LAG3', 'IL-8', 'HER2', 'ERa', 'EpCAM', 'E2F1', 'cycD3', 'cycB2', 'CDC25C', 'CD86', 'CD73', 'CD69', 'CD62L', 'CD56', 'CD4', 'CD25', 'CD19', 'CD27', 'CCR7', 'cCASP3'], margin=0, mask_value=0, transfer_cleanup_enabled=True, core_cleanup_enabled=True), additional_elements=[NormalizeStep(category='image_transformer', type='normalize', input='DAPI', output='DAPI_norm', keep=False, parameters=Params(low=1.0, high=99.5)), NormalizeStep(category='image_transformer', type='normalize', input='CD45', output='CD45_norm', keep=False, parameters=Params(low=1.0, high=99.5)), NormalizeStep(category='image_transformer', type='normalize', input='CD44', output='CD44_norm', keep=False, parameters=Params(low=1.0, high=99.5)), NormalizeStep(category='image_transformer', type='normalize', input='HLA1', output='HLA1_norm', keep=False, parameters=Params(low=1.0, high=99.5)), NormalizeStep(category='image_transformer', type='normalize', input='CD44', output='CD44_norm', keep=False, parameters=Params(low=1.0, high=99.5)), NormalizeStep(category='image_transformer', type='normalize', input='NaKATPase', output='NaKATPase_norm', keep=False, parameters=Params(low=1.0, high=99.5)), NormalizeStep(category='image_transformer', type='normalize', input='CD11C', output='CD11C_norm', keep=False, parameters=Params(low=1.0, high=99.5)), NormalizeStep(category='image_transformer', type='normalize', input='pCK26', output='pCK26_norm', keep=False, parameters=Params(low=1.0, high=99.5)), NormalizeStep(category='image_transformer', type='normalize', input='pS6', output='pS6_norm', keep=False, parameters=Params(low=1.0, high=99.5)), NormalizeStep(category='image_transformer', type='normalize', input='HES1', output='HES1_norm', keep=False, parameters=Params(low=1.0, high=99.5)), InstansegStep(category='object_segmenter', type='instanseg', input=['DAPI_norm', 'HLA1_norm', 'CD44_norm', 'NaKATPase_norm', 'CD11C_norm', 'CD45_norm', 'pCK26_norm', 'pS6_norm', 'HES1_norm'], output=['instanseg_nucleus_org', 'instanseg_cell_org'], keep=True, parameters=Params(model='fluorescence_nuclei_and_cells', pixel_size=0.3, resolve_cell_and_nucleus=True, cleanup_fragments=True, clean_cache=True)), BlobStep(category='mask_builder', type='blob', input='instanseg_nucleus_org', output='blob', keep=True, parameters={}), MultiplyStep(category='mask_builder', type='multiply', input=['instanseg_nucleus_org', 'blob'], output='instanseg_nucleus', keep=True, parameters={}), MultiplyStep(category='mask_builder', type='multiply', input=['instanseg_cell_org', 'blob'], output='instanseg_cell', keep=True, parameters={}), RingStep(category='mask_builder', type='ring', input=['instanseg_nucleus'], output='ring', keep=True, parameters=Params(outer=8, inner=2)), SubtractStep(category='mask_builder', type='subtract', input=['instanseg_cell', 'instanseg_nucleus'], output='cytoplasm', keep=True, parameters={})], quant=[QuantTask(name='instanseg_table', masks={'nucleus': 'instanseg_nucleus', 'cell': 'instanseg_cell', 'ring': 'ring', 'cyto': 'cytoplasm'}, layer_connection='instanseg_cell')], sdata_storage=StorageSettings(chunk_size=[1, 512, 512], max_pyramid_level=3, downscale=2), analysis_dir=WindowsPath('C:/BLCA-7_Analysis'), temp_dir=WindowsPath('C:/BLCA ...

# %% [markdown]
# ### Define the logger

# %%
log_file = settings.log_dir_path / f"cores_cutting_{datetime.now():%Y-%m-%d_%H-%M-%S}.log"

logger.remove()
l = logger.add(lambda msg: print(msg, end=""))
l = logger.add(log_file, level="DEBUG", enqueue=True)

# %% [markdown]
# ### Define cores for processing

# %%
df_path = settings.core_info_file_path.with_suffix('.pkl')

df = pd.read_pickle(df_path)
df.head()
# Out:
#   core_name  row_start  row_stop  column_start  column_stop  poly_type  \
# 0  Core_000     2304.0    7296.0        8000.0      13312.0  rectangle
# 1  Core_001     1984.0    7232.0       14400.0      19840.0  rectangle
# 2  Core_002     2304.0    7744.0       21952.0      26048.0  rectangle
# 3  Core_003     2496.0    7808.0       27200.0      32768.0  rectangle
# 4  Core_004     2560.0    8000.0       34048.0      39488.0  rectangle
#
#                                     polygon_vertices
# 0  [[2304.0, 13312.0], [7296.0, 13312.0], [7296.0...
# 1  [[1984.0, 19840.0], [7232.0, 19840.0], [7232.0...
# 2  [[2304.0, 26048.0], [7744.0, 26048.0], [7744.0...
# 3  [[2496.0, 32768.0], [7808.0, 32768.0], [7808.0...
# 4  [[2560.0, 39488.0], [8000.0, 39488.0], [8000.0...

# %%
# create a subset of cores (optional)
df = df[:1]
df
# Out:
#   core_name  row_start  row_stop  column_start  column_stop  poly_type  \
# 0  Core_000     2304.0    7296.0        8000.0      13312.0  rectangle
#
#                                     polygon_vertices
# 0  [[2304.0, 13312.0], [7296.0, 13312.0], [7296.0...

# %% [markdown]
# ## Local files

# %%
channel_map = discover_channels(Path(settings.general.image_dir),
                                include_channels=settings.core_cutting.include_channels,
                                exclude_channels=settings.core_cutting.exclude_channels,
                                use_markers=settings.core_cutting.use_markers,
                                ignore_markers=settings.core_cutting.ignore_markers)
# Out:
# 2025-10-17 13:30:57.022 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:80 - Discovered 131 channels:
# 2025-10-17 13:30:57.027 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 001_CDC25C <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_1.0.4_R000_FITC_CDC25C-AF488_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.028 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 001_DAPI <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_1.0.4_R000_DAPI__FINAL_F.ome.tif
# 2025-10-17 13:30:57.028 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 001_cycD3 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_1.0.4_R000_Cy7_cycD3-AF750_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.029 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 001_pH2AX <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_1.0.4_R000_Cy3_pH2AX-AF555_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.029 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 001_pRB <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_1.0.4_R000_Cy5_pRB-AF647_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.030 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 002_DAPI <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_2.0.4_R000_DAPI__FINAL_F.ome.tif
# 2025-10-17 13:30:57.030 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 002_cycA1 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_2.0.4_R000_Cy3_cycA1-AF555_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.031 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 002_cycB2 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_2.0.4_R000_Cy7_cycB2-AF750_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.032 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 002_cycE1 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_2.0.4_R000_Cy5_cycE1-AF647_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.033 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 002_cycE2 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_2.0.4_R000_FITC_cycE2-AF488_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.033 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 003_DAPI <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_3.0.4_R000_DAPI__FINAL_F.ome.tif
# 2025-10-17 13:30:57.034 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 003_Ki67 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_3.0.4_R000_Cy5_Ki67-AF647_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.035 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 003_RB <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_3.0.4_R000_Cy7_RB-AF750_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.036 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 003_cCASP3 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_3.0.4_R000_FITC_cCASP3-AF488_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.037 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 003_cycD1 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_3.0.4_R000_Cy3_cycD1-AF555_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.038 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 004_DAPI <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_4.0.4_R000_DAPI__FINAL_F.ome.tif
# 2025-10-17 13:30:57.038 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 004_E2F1 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_4.0.4_R000_Cy7_E2F1-AF750_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.039 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 004_HES1 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_4.0.4_R000_FITC_HES1-AF488_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.040 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 004_cycA2 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_4.0.4_R000_Cy3_cycA2-AF555_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.040 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 004_p53 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_4.0.4_R000_Cy5_p53-AF647_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.041 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 005_CDK6 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_5.0.4_R000_Cy5_CDK6-AF647_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.041 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 005_DAPI <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_5.0.4_R000_DAPI__FINAL_F.ome.tif
# 2025-10-17 13:30:57.043 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 005_bCat <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_5.0.4_R000_Cy3_bCat-AF555_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.044 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 005_p27 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_5.0.4_R000_Cy7_p27-AF750_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.044 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 005_p65 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_5.0.4_R000_FITC_p65-AF488_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.045 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 006_CycB1 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_6.0.4_R000_Cy3_CycB1-AF555_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.046 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 006_DAPI <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_6.0.4_R000_DAPI__FINAL_F.ome.tif
# 2025-10-17 13:30:57.047 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 006_PCNA <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_6.0.4_R000_Cy5_PCNA-AF647_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.048 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 006_Plk1 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_6.0.4_R000_FITC_Plk1-AF488_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.049 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 006_p-Cdc6 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_6.0.4_R000_Cy7_p-Cdc6-AF750_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.050 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 007_CDK4 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_7.0.4_R000_Cy7_CDK4-AF750_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.051 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 007_CDT1 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_7.0.4_R000_Cy5_CDT1-AF647_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.051 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 007_DAPI <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_7.0.4_R000_DAPI__FINAL_F.ome.tif
# 2025-10-17 13:30:57.051 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 007_VIM <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_7.0.4_R000_FITC_VIM-AF488_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.052 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 007_wee1 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_7.0.4_R000_Cy3_wee1-AF555_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.052 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 008_CDK2 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_8.0.4_R000_Cy7_CDK2-AF750_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.053 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 008_DAPI <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_8.0.4_R000_DAPI__FINAL_F.ome.tif
# 2025-10-17 13:30:57.054 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 008_ECad <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_8.0.4_R000_FITC_ECad-AF488_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.055 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 008_YAP1 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_8.0.4_R000_Cy3_YAP1-AF555_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.055 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 008_pRB <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_8.0.4_R000_Cy5_pRB-AF647_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.056 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 009_CD45RO <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_9.0.4_R000_FITC_CD45RO-AF488_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.056 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 009_DAPI <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_9.0.4_R000_DAPI__FINAL_F.ome.tif
# 2025-10-17 13:30:57.057 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 009_p21 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_9.0.4_R000_Cy5_p21-AF647_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.058 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 009_pCK26 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_9.0.4_R000_Cy7_pCK26-AF750_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.058 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 009_pS6 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_9.0.4_R000_Cy3_pS6-AF555_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.058 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 010_CD127 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_10.0.4_R000_FITC_CD127-AF488_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.059 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 010_DAPI <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_10.0.4_R000_DAPI__FINAL_F.ome.tif
# 2025-10-17 13:30:57.059 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 010_PDL1 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_10.0.4_R000_Cy7_PDL1-AF750_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.061 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 010_p16 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_10.0.4_R000_Cy5_p16-AF647_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.061 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 010_p38 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_10.0.4_R000_Cy3_p38-AF555_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.062 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 011_CCR7 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_11.0.4_R000_FITC_CCR7-AF488_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.063 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 011_CD3 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_11.0.4_R000_Cy3_CD3-AF555_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.063 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 011_CD45 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_11.0.4_R000_Cy7_CD45-AF750_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.063 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 011_DAPI <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_11.0.4_R000_DAPI__FINAL_F.ome.tif
# 2025-10-17 13:30:57.064 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 011_SKP2 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_11.0.4_R000_Cy5_SKP2-AF647_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.064 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 012_CD11C <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_12.0.4_R000_Cy3_CD11C-AF555_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.065 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 012_CD20 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_12.0.4_R000_Cy7_CD20-AF750_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.065 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 012_DAPI <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_12.0.4_R000_DAPI__FINAL_F.ome.tif
# 2025-10-17 13:30:57.066 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 012_IL-8 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_12.0.4_R000_FITC_IL-8-AF488_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.066 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 012_cMYC <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_12.0.4_R000_Cy5_cMYC-AF647_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.067 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 013_CD68 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_13.0.4_R000_Cy3_CD68-AF555_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.067 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 013_CD69 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_13.0.4_R000_Cy5_CD69-AF647_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.068 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 013_DAPI <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_13.0.4_R000_DAPI__FINAL_F.ome.tif
# 2025-10-17 13:30:57.068 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 013_PH3 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_13.0.4_R000_Cy7_PH3-AF750_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.069 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 013_TNFa <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_13.0.4_R000_FITC_TNFa-AF488_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.069 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 014_CD4 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_14.0.4_R000_Cy5_CD4-AF647_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.069 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 014_DAPI <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_14.0.4_R000_DAPI__FINAL_F.ome.tif
# 2025-10-17 13:30:57.070 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 014_FOXP3 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_14.0.4_R000_Cy7_FOXP3-AF750_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.070 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 014_PD-1 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_14.0.4_R000_Cy3_PD-1-AF555_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.071 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 014_Snail1 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_14.0.4_R000_FITC_Snail1-AF488_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.071 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 015_Antibody1 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_15.0.4_R000_FITC_Antibody1_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.071 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 015_CD11b <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_15.0.4_R000_Cy3_CD11b-AF555_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.071 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 015_CD8a <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_15.0.4_R000_Cy5_CD8a-AF647_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.073 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 015_DAPI <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_15.0.4_R000_DAPI__FINAL_F.ome.tif
# 2025-10-17 13:30:57.073 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 015_NaKATPase <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_15.0.4_R000_Cy7_NaKATPase-AF750_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.073 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 016_CD31 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_16.0.4_R000_Cy3_CD31-AF555_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.073 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 016_CD44 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_16.0.4_R000_Cy7_CD44-AF750_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.074 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 016_DAPI <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_16.0.4_R000_DAPI__FINAL_F.ome.tif
# 2025-10-17 13:30:57.074 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 016_pERK <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_16.0.4_R000_Cy5_pERK-AF647_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.075 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 017_CD27 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_17.0.4_R000_Cy3_CD27-AF555_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.075 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 017_CDC6 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_17.0.4_R000_Cy7_CDC6-AF750_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.076 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 017_DAPI <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_17.0.4_R000_DAPI__FINAL_F.ome.tif
# 2025-10-17 13:30:57.076 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 017_pAKT <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_17.0.4_R000_Cy5_pAKT-AF647_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.076 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 018_DAPI <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_18.0.4_R000_DAPI__FINAL_F.ome.tif
# 2025-10-17 13:30:57.078 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 018_GranzymeB <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_18.0.4_R000_Cy3_GranzymeB-AF555_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.079 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 018_TGFb1 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_18.0.4_R000_Cy5_TGFb1-AF647_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.080 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 018_p130 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_18.0.4_R000_Cy7_p130-AF750_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.080 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 019_CD163 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_19.0.4_R000_Cy3_CD163-AF555_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.081 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 019_DAPI <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_19.0.4_R000_DAPI__FINAL_F.ome.tif
# 2025-10-17 13:30:57.081 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 019_Fibro <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_19.0.4_R000_Cy5_Fibro-AF647_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.081 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 019_p-p130 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_19.0.4_R000_Cy7_p-p130-AF750_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.082 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 020_DAPI <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_20.0.4_R000_DAPI__FINAL_F.ome.tif
# 2025-10-17 13:30:57.083 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 020_EpCAM <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_20.0.4_R000_Cy5_EpCAM-AF647_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.083 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 020_HLA1 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_20.0.4_R000_Cy3_HLA1-AF555_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.083 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 020_pATR <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_20.0.4_R000_Cy7_pATR-AF750_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.084 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 021_53BP1 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_21.0.4_R000_Cy7_53BP1-AF750_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.084 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 021_DAPI <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_21.0.4_R000_DAPI__FINAL_F.ome.tif
# 2025-10-17 13:30:57.085 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 021_IL6 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_21.0.4_R000_Cy5_IL6-AF647_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.085 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 021_SMA <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_21.0.4_R000_Cy3_SMA-Cy3_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.086 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 022_CD19 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_22.0.4_R000_Cy5_CD19-AF647_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.086 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 022_CD56 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_22.0.4_R000_Cy7_CD56-AF750_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.086 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 022_DAPI <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_22.0.4_R000_DAPI__FINAL_F.ome.tif
# 2025-10-17 13:30:57.087 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 023_CD25 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_23.0.4_R000_Cy5_CD25-AF647_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.087 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 023_CD73 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_23.0.4_R000_Cy7_CD73-AF750_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.088 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 023_DAPI <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_23.0.4_R000_DAPI__FINAL_F.ome.tif
# 2025-10-17 13:30:57.088 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 024_DAPI <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_24.0.4_R000_DAPI__FINAL_F.ome.tif
# 2025-10-17 13:30:57.089 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 024_HLADR <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_24.0.4_R000_Cy7_HLADR-AF750_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.089 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 024_PML <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_24.0.4_R000_Cy5_PML-AF647_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.089 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 025_CD86 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_25.0.4_R000_Cy5_CD86-AF647_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.090 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 025_DAPI <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_25.0.4_R000_DAPI__FINAL_F.ome.tif
# 2025-10-17 13:30:57.090 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 025_ECad <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_25.0.4_R000_Cy3_ECad-AF555_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.090 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 025_LaminB1 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_25.0.4_R000_FITC_LaminB1-AF488_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.091 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 025_p27 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_25.0.4_R000_Cy7_p27-AF750_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.091 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 026_DAPI <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_26.0.4_R000_DAPI__FINAL_F.ome.tif
# 2025-10-17 13:30:57.091 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 026_ERa <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_26.0.4_R000_Cy3_ERa-AF555_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.093 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 026_HER2 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_26.0.4_R000_FITC_HER2-AF488_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.093 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 026_HIF1a <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_26.0.4_R000_Cy5_HIF1a-AF647_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.093 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 026_ProgRc <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_26.0.4_R000_Cy7_ProgRc-AF750_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.093 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 027_CD4 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_27.0.4_R000_Cy5_CD4-AF647_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.094 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 027_CD45RO <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_27.0.4_R000_FITC_CD45RO-AF488_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.094 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 027_CD68 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_27.0.4_R000_Cy3_CD68-AF555_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.094 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 027_DAPI <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_27.0.4_R000_DAPI__FINAL_F.ome.tif
# 2025-10-17 13:30:57.095 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 027_FOXP3 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_27.0.4_R000_Cy7_FOXP3-AF750_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.095 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 028_CD86 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_28.0.4_R000_Cy5_CD86-AF647_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.095 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 028_DAPI <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_28.0.4_R000_DAPI__FINAL_F.ome.tif
# 2025-10-17 13:30:57.096 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 028_LAG3 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_28.0.4_R000_Cy7_LAG3-AF750_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.097 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 028_p65 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_28.0.4_R000_Cy3_p65-AF555_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.097 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 029_CD4 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_29.0.4_R000_Cy3_CD4-AF555_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.097 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 029_CD62L <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_29.0.4_R000_Cy5_CD62L-AF647_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.098 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 029_Coll3 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_29.0.4_R000_Cy7_Coll3-AF750_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.098 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:82 - 029_DAPI <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_29.0.4_R000_DAPI__FINAL_F.ome.tif
# 2025-10-17 13:30:57.098 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:121 - Restricting to use_markers = ['DAPI', 'CD45', 'CD44', 'HLA1', 'CD44', 'NaKATPase', 'CD11C', 'pCK26', 'pS6', 'HES1']
# 2025-10-17 13:30:57.099 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:122 - Final filtered channels: ['DAPI', 'HES1', 'pCK26', 'pS6', 'CD45', 'CD11C', 'NaKATPase', 'CD44', 'HLA1']
# 2025-10-17 13:30:57.099 | WARNING  | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:127 - Requested ignore_marker 'Antibody1' not found.
# 2025-10-17 13:30:57.099 | WARNING  | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:127 - Requested ignore_marker 'TNFa' not found.
# 2025-10-17 13:30:57.100 | WARNING  | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:127 - Requested ignore_marker 'Snail1' not found.
# 2025-10-17 13:30:57.100 | WARNING  | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:127 - Requested ignore_marker 'SKP2' not found.
# 2025-10-17 13:30:57.101 | WARNING  | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:127 - Requested ignore_marker 'ProgRc' not found.
# 2025-10-17 13:30:57.101 | WARNING  | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:127 - Requested ignore_marker 'Plk1' not found.
# 2025-10-17 13:30:57.102 | WARNING  | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:127 - Requested ignore_marker 'PH3' not found.
# 2025-10-17 13:30:57.102 | WARNING  | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:127 - Requested ignore_marker 'PDL1' not found.
# 2025-10-17 13:30:57.102 | WARNING  | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:127 - Requested ignore_marker 'p65' not found.
# 2025-10-17 13:30:57.103 | WARNING  | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:127 - Requested ignore_marker 'p130' not found.
# 2025-10-17 13:30:57.103 | WARNING  | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:127 - Requested ignore_marker 'p-p130' not found.
# 2025-10-17 13:30:57.103 | WARNING  | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:127 - Requested ignore_marker 'p-Cdc6' not found.
# 2025-10-17 13:30:57.103 | WARNING  | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:127 - Requested ignore_marker 'LAG3' not found.
# 2025-10-17 13:30:57.103 | WARNING  | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:127 - Requested ignore_marker 'IL-8' not found.
# 2025-10-17 13:30:57.104 | WARNING  | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:127 - Requested ignore_marker 'HER2' not found.
# 2025-10-17 13:30:57.104 | WARNING  | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:127 - Requested ignore_marker 'ERa' not found.
# 2025-10-17 13:30:57.104 | WARNING  | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:127 - Requested ignore_marker 'EpCAM' not found.
# 2025-10-17 13:30:57.104 | WARNING  | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:127 - Requested ignore_marker 'E2F1' not found.
# 2025-10-17 13:30:57.105 | WARNING  | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:127 - Requested ignore_marker 'cycD3' not found.
# 2025-10-17 13:30:57.105 | WARNING  | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:127 - Requested ignore_marker 'cycB2' not found.
# 2025-10-17 13:30:57.105 | WARNING  | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:127 - Requested ignore_marker 'CDC25C' not found.
# 2025-10-17 13:30:57.106 | WARNING  | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:127 - Requested ignore_marker 'CD86' not found.
# 2025-10-17 13:30:57.106 | WARNING  | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:127 - Requested ignore_marker 'CD73' not found.
# 2025-10-17 13:30:57.106 | WARNING  | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:127 - Requested ignore_marker 'CD69' not found.
# 2025-10-17 13:30:57.107 | WARNING  | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:127 - Requested ignore_marker 'CD62L' not found.
# 2025-10-17 13:30:57.107 | WARNING  | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:127 - Requested ignore_marker 'CD56' not found.
# 2025-10-17 13:30:57.107 | WARNING  | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:127 - Requested ignore_marker 'CD4' not found.
# 2025-10-17 13:30:57.107 | WARNING  | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:127 - Requested ignore_marker 'CD25' not found.
# 2025-10-17 13:30:57.108 | WARNING  | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:127 - Requested ignore_marker 'CD19' not found.
# 2025-10-17 13:30:57.108 | WARNING  | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:127 - Requested ignore_marker 'CD27' not found.
# 2025-10-17 13:30:57.108 | WARNING  | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:127 - Requested ignore_marker 'CCR7' not found.
# 2025-10-17 13:30:57.109 | WARNING  | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:127 - Requested ignore_marker 'cCASP3' not found.
# 2025-10-17 13:30:57.109 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:132 - Ignoring markers = ['Antibody1', 'TNFa', 'Snail1', 'SKP2', 'ProgRc', 'Plk1', 'PH3', 'PDL1', 'p65', 'p130', 'p-p130', 'p-Cdc6', 'LAG3', 'IL-8', 'HER2', 'ERa', 'EpCAM', 'E2F1', 'cycD3', 'cycB2', 'CDC25C', 'CD86', 'CD73', 'CD69', 'CD62L', 'CD56', 'CD4', 'CD25', 'CD19', 'CD27', 'CCR7', 'cCASP3']
# 2025-10-17 13:30:57.109 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:133 - Final filtered channels: ['DAPI', 'HES1', 'pCK26', 'pS6', 'CD45', 'CD11C', 'NaKATPase', 'CD44', 'HLA1']
# 2025-10-17 13:30:57.109 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:139 - Final selected channels 9:
# 2025-10-17 13:30:57.110 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:141 -   Channel: CD11C <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_12.0.4_R000_Cy3_CD11C-AF555_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.110 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:141 -   Channel: CD44 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_16.0.4_R000_Cy7_CD44-AF750_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.110 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:141 -   Channel: CD45 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_11.0.4_R000_Cy7_CD45-AF750_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.111 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:141 -   Channel: DAPI <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_1.0.4_R000_DAPI__FINAL_F.ome.tif
# 2025-10-17 13:30:57.111 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:141 -   Channel: HES1 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_4.0.4_R000_FITC_HES1-AF488_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.111 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:141 -   Channel: HLA1 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_20.0.4_R000_Cy3_HLA1-AF555_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.111 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:141 -   Channel: NaKATPase <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_15.0.4_R000_Cy7_NaKATPase-AF750_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.113 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:141 -   Channel: pCK26 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_9.0.4_R000_Cy7_pCK26-AF750_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.114 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:141 -   Channel: pS6 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_9.0.4_R000_Cy3_pS6-AF555_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.114 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:143 - OME-TIFF files not used in final channel selection 122:
# 2025-10-17 13:30:57.114 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:145 -   Unused: Channel 001_CDC25C <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_1.0.4_R000_FITC_CDC25C-AF488_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.114 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:145 -   Unused: Channel 001_cycD3 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_1.0.4_R000_Cy7_cycD3-AF750_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.115 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:145 -   Unused: Channel 001_pH2AX <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_1.0.4_R000_Cy3_pH2AX-AF555_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.115 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:145 -   Unused: Channel 001_pRB <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_1.0.4_R000_Cy5_pRB-AF647_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.115 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:145 -   Unused: Channel 002_DAPI <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_2.0.4_R000_DAPI__FINAL_F.ome.tif
# 2025-10-17 13:30:57.116 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:145 -   Unused: Channel 002_cycA1 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_2.0.4_R000_Cy3_cycA1-AF555_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.116 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:145 -   Unused: Channel 002_cycB2 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_2.0.4_R000_Cy7_cycB2-AF750_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.116 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:145 -   Unused: Channel 002_cycE1 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_2.0.4_R000_Cy5_cycE1-AF647_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.116 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:145 -   Unused: Channel 002_cycE2 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_2.0.4_R000_FITC_cycE2-AF488_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.117 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:145 -   Unused: Channel 003_DAPI <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_3.0.4_R000_DAPI__FINAL_F.ome.tif
# 2025-10-17 13:30:57.117 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:145 -   Unused: Channel 003_Ki67 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_3.0.4_R000_Cy5_Ki67-AF647_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.117 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:145 -   Unused: Channel 003_RB <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_3.0.4_R000_Cy7_RB-AF750_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.117 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:145 -   Unused: Channel 003_cCASP3 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_3.0.4_R000_FITC_cCASP3-AF488_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.118 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:145 -   Unused: Channel 003_cycD1 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_3.0.4_R000_Cy3_cycD1-AF555_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.118 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:145 -   Unused: Channel 004_DAPI <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_4.0.4_R000_DAPI__FINAL_F.ome.tif
# 2025-10-17 13:30:57.118 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:145 -   Unused: Channel 004_E2F1 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_4.0.4_R000_Cy7_E2F1-AF750_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.118 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:145 -   Unused: Channel 004_cycA2 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_4.0.4_R000_Cy3_cycA2-AF555_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.119 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:145 -   Unused: Channel 004_p53 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_4.0.4_R000_Cy5_p53-AF647_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.119 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:145 -   Unused: Channel 005_CDK6 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_5.0.4_R000_Cy5_CDK6-AF647_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.119 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:145 -   Unused: Channel 005_DAPI <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_5.0.4_R000_DAPI__FINAL_F.ome.tif
# 2025-10-17 13:30:57.120 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:145 -   Unused: Channel 005_bCat <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_5.0.4_R000_Cy3_bCat-AF555_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.120 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:145 -   Unused: Channel 005_p27 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_5.0.4_R000_Cy7_p27-AF750_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.120 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:145 -   Unused: Channel 005_p65 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_5.0.4_R000_FITC_p65-AF488_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.120 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:145 -   Unused: Channel 006_CycB1 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_6.0.4_R000_Cy3_CycB1-AF555_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.121 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:145 -   Unused: Channel 006_DAPI <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_6.0.4_R000_DAPI__FINAL_F.ome.tif
# 2025-10-17 13:30:57.121 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:145 -   Unused: Channel 006_PCNA <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_6.0.4_R000_Cy5_PCNA-AF647_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.121 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:145 -   Unused: Channel 006_Plk1 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_6.0.4_R000_FITC_Plk1-AF488_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.121 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:145 -   Unused: Channel 006_p-Cdc6 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_6.0.4_R000_Cy7_p-Cdc6-AF750_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.122 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:145 -   Unused: Channel 007_CDK4 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_7.0.4_R000_Cy7_CDK4-AF750_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.122 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:145 -   Unused: Channel 007_CDT1 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_7.0.4_R000_Cy5_CDT1-AF647_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.122 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:145 -   Unused: Channel 007_DAPI <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_7.0.4_R000_DAPI__FINAL_F.ome.tif
# 2025-10-17 13:30:57.123 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:145 -   Unused: Channel 007_VIM <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_7.0.4_R000_FITC_VIM-AF488_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.123 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:145 -   Unused: Channel 007_wee1 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_7.0.4_R000_Cy3_wee1-AF555_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.124 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:145 -   Unused: Channel 008_CDK2 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_8.0.4_R000_Cy7_CDK2-AF750_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.124 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:145 -   Unused: Channel 008_DAPI <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_8.0.4_R000_DAPI__FINAL_F.ome.tif
# 2025-10-17 13:30:57.124 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:145 -   Unused: Channel 008_ECad <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_8.0.4_R000_FITC_ECad-AF488_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.125 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:145 -   Unused: Channel 008_YAP1 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_8.0.4_R000_Cy3_YAP1-AF555_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.125 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:145 -   Unused: Channel 008_pRB <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_8.0.4_R000_Cy5_pRB-AF647_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.125 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:145 -   Unused: Channel 009_CD45RO <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_9.0.4_R000_FITC_CD45RO-AF488_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.125 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:145 -   Unused: Channel 009_DAPI <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_9.0.4_R000_DAPI__FINAL_F.ome.tif
# 2025-10-17 13:30:57.126 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:145 -   Unused: Channel 009_p21 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_9.0.4_R000_Cy5_p21-AF647_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.126 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:145 -   Unused: Channel 010_CD127 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_10.0.4_R000_FITC_CD127-AF488_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.126 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:145 -   Unused: Channel 010_DAPI <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_10.0.4_R000_DAPI__FINAL_F.ome.tif
# 2025-10-17 13:30:57.126 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:145 -   Unused: Channel 010_PDL1 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_10.0.4_R000_Cy7_PDL1-AF750_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.127 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:145 -   Unused: Channel 010_p16 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_10.0.4_R000_Cy5_p16-AF647_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.127 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:145 -   Unused: Channel 010_p38 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_10.0.4_R000_Cy3_p38-AF555_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.127 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:145 -   Unused: Channel 011_CCR7 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_11.0.4_R000_FITC_CCR7-AF488_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.128 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:145 -   Unused: Channel 011_CD3 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_11.0.4_R000_Cy3_CD3-AF555_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.128 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:145 -   Unused: Channel 011_DAPI <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_11.0.4_R000_DAPI__FINAL_F.ome.tif
# 2025-10-17 13:30:57.128 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:145 -   Unused: Channel 011_SKP2 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_11.0.4_R000_Cy5_SKP2-AF647_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.129 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:145 -   Unused: Channel 012_CD20 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_12.0.4_R000_Cy7_CD20-AF750_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.129 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:145 -   Unused: Channel 012_DAPI <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_12.0.4_R000_DAPI__FINAL_F.ome.tif
# 2025-10-17 13:30:57.130 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:145 -   Unused: Channel 012_IL-8 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_12.0.4_R000_FITC_IL-8-AF488_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.130 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:145 -   Unused: Channel 012_cMYC <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_12.0.4_R000_Cy5_cMYC-AF647_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.130 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:145 -   Unused: Channel 013_CD68 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_13.0.4_R000_Cy3_CD68-AF555_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.130 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:145 -   Unused: Channel 013_CD69 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_13.0.4_R000_Cy5_CD69-AF647_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.131 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:145 -   Unused: Channel 013_DAPI <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_13.0.4_R000_DAPI__FINAL_F.ome.tif
# 2025-10-17 13:30:57.131 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:145 -   Unused: Channel 013_PH3 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_13.0.4_R000_Cy7_PH3-AF750_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.131 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:145 -   Unused: Channel 013_TNFa <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_13.0.4_R000_FITC_TNFa-AF488_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.133 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:145 -   Unused: Channel 014_CD4 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_14.0.4_R000_Cy5_CD4-AF647_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.133 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:145 -   Unused: Channel 014_DAPI <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_14.0.4_R000_DAPI__FINAL_F.ome.tif
# 2025-10-17 13:30:57.133 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:145 -   Unused: Channel 014_FOXP3 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_14.0.4_R000_Cy7_FOXP3-AF750_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.134 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:145 -   Unused: Channel 014_PD-1 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_14.0.4_R000_Cy3_PD-1-AF555_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.134 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:145 -   Unused: Channel 014_Snail1 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_14.0.4_R000_FITC_Snail1-AF488_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.134 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:145 -   Unused: Channel 015_Antibody1 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_15.0.4_R000_FITC_Antibody1_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.135 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:145 -   Unused: Channel 015_CD11b <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_15.0.4_R000_Cy3_CD11b-AF555_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.135 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:145 -   Unused: Channel 015_CD8a <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_15.0.4_R000_Cy5_CD8a-AF647_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.135 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:145 -   Unused: Channel 015_DAPI <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_15.0.4_R000_DAPI__FINAL_F.ome.tif
# 2025-10-17 13:30:57.135 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:145 -   Unused: Channel 016_CD31 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_16.0.4_R000_Cy3_CD31-AF555_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.136 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:145 -   Unused: Channel 016_DAPI <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_16.0.4_R000_DAPI__FINAL_F.ome.tif
# 2025-10-17 13:30:57.136 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:145 -   Unused: Channel 016_pERK <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_16.0.4_R000_Cy5_pERK-AF647_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.136 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:145 -   Unused: Channel 017_CD27 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_17.0.4_R000_Cy3_CD27-AF555_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.136 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:145 -   Unused: Channel 017_CDC6 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_17.0.4_R000_Cy7_CDC6-AF750_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.137 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:145 -   Unused: Channel 017_DAPI <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_17.0.4_R000_DAPI__FINAL_F.ome.tif
# 2025-10-17 13:30:57.137 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:145 -   Unused: Channel 017_pAKT <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_17.0.4_R000_Cy5_pAKT-AF647_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.137 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:145 -   Unused: Channel 018_DAPI <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_18.0.4_R000_DAPI__FINAL_F.ome.tif
# 2025-10-17 13:30:57.137 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:145 -   Unused: Channel 018_GranzymeB <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_18.0.4_R000_Cy3_GranzymeB-AF555_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.137 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:145 -   Unused: Channel 018_TGFb1 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_18.0.4_R000_Cy5_TGFb1-AF647_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.138 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:145 -   Unused: Channel 018_p130 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_18.0.4_R000_Cy7_p130-AF750_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.138 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:145 -   Unused: Channel 019_CD163 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_19.0.4_R000_Cy3_CD163-AF555_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.138 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:145 -   Unused: Channel 019_DAPI <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_19.0.4_R000_DAPI__FINAL_F.ome.tif
# 2025-10-17 13:30:57.138 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:145 -   Unused: Channel 019_Fibro <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_19.0.4_R000_Cy5_Fibro-AF647_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.139 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:145 -   Unused: Channel 019_p-p130 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_19.0.4_R000_Cy7_p-p130-AF750_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.139 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:145 -   Unused: Channel 020_DAPI <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_20.0.4_R000_DAPI__FINAL_F.ome.tif
# 2025-10-17 13:30:57.139 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:145 -   Unused: Channel 020_EpCAM <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_20.0.4_R000_Cy5_EpCAM-AF647_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.139 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:145 -   Unused: Channel 020_pATR <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_20.0.4_R000_Cy7_pATR-AF750_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.140 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:145 -   Unused: Channel 021_53BP1 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_21.0.4_R000_Cy7_53BP1-AF750_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.140 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:145 -   Unused: Channel 021_DAPI <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_21.0.4_R000_DAPI__FINAL_F.ome.tif
# 2025-10-17 13:30:57.140 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:145 -   Unused: Channel 021_IL6 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_21.0.4_R000_Cy5_IL6-AF647_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.140 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:145 -   Unused: Channel 021_SMA <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_21.0.4_R000_Cy3_SMA-Cy3_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.141 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:145 -   Unused: Channel 022_CD19 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_22.0.4_R000_Cy5_CD19-AF647_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.141 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:145 -   Unused: Channel 022_CD56 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_22.0.4_R000_Cy7_CD56-AF750_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.141 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:145 -   Unused: Channel 022_DAPI <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_22.0.4_R000_DAPI__FINAL_F.ome.tif
# 2025-10-17 13:30:57.141 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:145 -   Unused: Channel 023_CD25 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_23.0.4_R000_Cy5_CD25-AF647_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.141 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:145 -   Unused: Channel 023_CD73 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_23.0.4_R000_Cy7_CD73-AF750_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.141 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:145 -   Unused: Channel 023_DAPI <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_23.0.4_R000_DAPI__FINAL_F.ome.tif
# 2025-10-17 13:30:57.141 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:145 -   Unused: Channel 024_DAPI <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_24.0.4_R000_DAPI__FINAL_F.ome.tif
# 2025-10-17 13:30:57.142 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:145 -   Unused: Channel 024_HLADR <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_24.0.4_R000_Cy7_HLADR-AF750_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.142 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:145 -   Unused: Channel 024_PML <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_24.0.4_R000_Cy5_PML-AF647_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.142 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:145 -   Unused: Channel 025_CD86 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_25.0.4_R000_Cy5_CD86-AF647_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.142 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:145 -   Unused: Channel 025_DAPI <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_25.0.4_R000_DAPI__FINAL_F.ome.tif
# 2025-10-17 13:30:57.143 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:145 -   Unused: Channel 025_ECad <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_25.0.4_R000_Cy3_ECad-AF555_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.144 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:145 -   Unused: Channel 025_LaminB1 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_25.0.4_R000_FITC_LaminB1-AF488_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.144 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:145 -   Unused: Channel 025_p27 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_25.0.4_R000_Cy7_p27-AF750_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.145 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:145 -   Unused: Channel 026_DAPI <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_26.0.4_R000_DAPI__FINAL_F.ome.tif
# 2025-10-17 13:30:57.146 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:145 -   Unused: Channel 026_ERa <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_26.0.4_R000_Cy3_ERa-AF555_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.146 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:145 -   Unused: Channel 026_HER2 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_26.0.4_R000_FITC_HER2-AF488_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.146 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:145 -   Unused: Channel 026_HIF1a <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_26.0.4_R000_Cy5_HIF1a-AF647_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.147 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:145 -   Unused: Channel 026_ProgRc <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_26.0.4_R000_Cy7_ProgRc-AF750_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.147 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:145 -   Unused: Channel 027_CD4 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_27.0.4_R000_Cy5_CD4-AF647_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.147 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:145 -   Unused: Channel 027_CD45RO <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_27.0.4_R000_FITC_CD45RO-AF488_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.147 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:145 -   Unused: Channel 027_CD68 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_27.0.4_R000_Cy3_CD68-AF555_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.147 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:145 -   Unused: Channel 027_DAPI <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_27.0.4_R000_DAPI__FINAL_F.ome.tif
# 2025-10-17 13:30:57.148 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:145 -   Unused: Channel 027_FOXP3 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_27.0.4_R000_Cy7_FOXP3-AF750_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.148 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:145 -   Unused: Channel 028_CD86 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_28.0.4_R000_Cy5_CD86-AF647_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.148 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:145 -   Unused: Channel 028_DAPI <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_28.0.4_R000_DAPI__FINAL_F.ome.tif
# 2025-10-17 13:30:57.149 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:145 -   Unused: Channel 028_LAG3 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_28.0.4_R000_Cy7_LAG3-AF750_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.149 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:145 -   Unused: Channel 028_p65 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_28.0.4_R000_Cy3_p65-AF555_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.149 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:145 -   Unused: Channel 029_CD4 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_29.0.4_R000_Cy3_CD4-AF555_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.150 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:145 -   Unused: Channel 029_CD62L <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_29.0.4_R000_Cy5_CD62L-AF647_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.150 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:145 -   Unused: Channel 029_Coll3 <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_29.0.4_R000_Cy7_Coll3-AF750_FINAL_AFR_F.ome.tif
# 2025-10-17 13:30:57.150 | INFO     | multiplex_pipeline.core_cutting.channel_scanner:scan_channels_from_list:145 -   Unused: Channel 029_DAPI <- R:\CellDive\BLCA-7\BLCA-7_Final\BLCA-7_29.0.4_R000_DAPI__FINAL_F.ome.tif

# %%
# # for tests you can request a small set of channels here
# # then send 'short_map' to the controller instead of 'channel_map'
# selected_keys = ["DAPI", "CD3"]
# short_map = {k: channel_map[k] for k in selected_keys if k in channel_map}
# short_map
# Out:
# {'DAPI': 'R:\\CellDive\\BLCA-1B\\BLCA-1B_Final\\BLCA-1B_1.0.4_R000_DAPI__FINAL_F.ome.tif',
#  'CD3': 'R:\\CellDive\\BLCA-1B\\BLCA-1B_Final\\BLCA-1B_11.0.4_R000_Cy3_CD3-AF555_FINAL_AFR_F.ome.tif'}

# %%
strategy = LocalFileStrategy()

controller = CorePreparationController(
    metadata_df = df, # df defines which cores to process
    image_paths = channel_map, # defines which channels to use
    temp_dir = settings.cores_dir_tif_path,
    output_dir = settings.cores_dir_output_path,
    file_strategy = strategy,
    margin = settings.core_cutting.margin,
    mask_value = settings.core_cutting.mask_value,
    max_pyramid_levels = settings.sdata_storage.max_pyramid_level,
    chunk_size = settings.sdata_storage.chunk_size,
    downscale = settings.sdata_storage.chunk_size,
)

controller.run()
# Out:
# 2025-10-17 13:30:59.925 | INFO     | multiplex_pipeline.core_cutting.controller:run:117 - Starting controller run loop...
# 2025-10-17 13:31:02.439 | DEBUG    | multiplex_pipeline.core_cutting.controller:cut_channel:93 - Cut and saved core Core_000, channel DAPI
# 2025-10-17 13:31:02.453 | DEBUG    | multiplex_pipeline.core_cutting.controller:cut_channel:100 - Closed file handle for channel DAPI
# 2025-10-17 13:31:04.376 | DEBUG    | multiplex_pipeline.core_cutting.controller:cut_channel:93 - Cut and saved core Core_000, channel HES1
# 2025-10-17 13:31:04.399 | DEBUG    | multiplex_pipeline.core_cutting.controller:cut_channel:100 - Closed file handle for channel HES1
# 2025-10-17 13:31:06.370 | DEBUG    | multiplex_pipeline.core_cutting.controller:cut_channel:93 - Cut and saved core Core_000, channel pCK26
# 2025-10-17 13:31:06.397 | DEBUG    | multiplex_pipeline.core_cutting.controller:cut_channel:100 - Closed file handle for channel pCK26
# 2025-10-17 13:31:08.208 | DEBUG    | multiplex_pipeline.core_cutting.controller:cut_channel:93 - Cut and saved core Core_000, channel pS6
# 2025-10-17 13:31:08.219 | DEBUG    | multiplex_pipeline.core_cutting.controller:cut_channel:100 - Closed file handle for channel pS6
# 2025-10-17 13:31:10.394 | DEBUG    | multiplex_pipeline.core_cutting.controller:cut_channel:93 - Cut and saved core Core_000, channel CD45
# 2025-10-17 13:31:10.419 | DEBUG    | multiplex_pipeline.core_cutting.controller:cut_channel:100 - Closed file handle for channel CD45
# 2025-10-17 13:31:12.209 | DEBUG    | multiplex_pipeline.core_cutting.controller:cut_channel:93 - Cut and saved core Core_000, channel CD11C
# 2025-10-17 13:31:12.231 | DEBUG    | multiplex_pipeline.core_cutting.controller:cut_channel:100 - Closed file handle for channel CD11C
# 2025-10-17 13:31:14.414 | DEBUG    | multiplex_pipeline.core_cutting.controller:cut_channel:93 - Cut and saved core Core_000, channel NaKATPase
# 2025-10-17 13:31:14.436 | DEBUG    | multiplex_pipeline.core_cutting.controller:cut_channel:100 - Closed file handle for channel NaKATPase
# 2025-10-17 13:31:16.327 | DEBUG    | multiplex_pipeline.core_cutting.controller:cut_channel:93 - Cut and saved core Core_000, channel CD44
# 2025-10-17 13:31:16.352 | DEBUG    | multiplex_pipeline.core_cutting.controller:cut_channel:100 - Closed file handle for channel CD44
# 2025-10-17 13:31:17.967 | DEBUG    | multiplex_pipeline.core_cutting.controller:cut_channel:93 - Cut and saved core Core_000, channel HLA1
# 2025-10-17 13:31:17.988 | DEBUG    | multiplex_pipeline.core_cutting.controller:cut_channel:100 - Closed file handle for channel HLA1
# 2025-10-17 13:31:18.000 | INFO     | multiplex_pipeline.core_cutting.controller:try_assemble_ready_cores:106 - Assembling full core Core_000
# 2025-10-17 13:31:19.405 | INFO     | multiplex_pipeline.core_cutting.assembler:assemble_core:102 - Core 'Core_000' assembled with channels: ['CD11C', 'CD44', 'CD45', 'DAPI', 'HES1', 'HLA1', 'NaKATPase', 'pCK26', 'pS6']
# INFO     The Zarr backing store has been changed from None the new file path:
#          C:\BLCA-7_Analysis\cores\Core_000.zarr
# 2025-10-17 13:31:27.096 | DEBUG    | multiplex_pipeline.core_cutting.assembler:_cleanup_core_files:126 - Deleted intermediate TIFF: C:\BLCA-7_Analysis\temp\Core_000\CD11C.tiff
# 2025-10-17 13:31:27.111 | DEBUG    | multiplex_pipeline.core_cutting.assembler:_cleanup_core_files:126 - Deleted intermediate TIFF: C:\BLCA-7_Analysis\temp\Core_000\CD44.tiff
# 2025-10-17 13:31:27.122 | DEBUG    | multiplex_pipeline.core_cutting.assembler:_cleanup_core_files:126 - Deleted intermediate TIFF: C:\BLCA-7_Analysis\temp\Core_000\CD45.tiff
# 2025-10-17 13:31:27.138 | DEBUG    | multiplex_pipeline.core_cutting.assembler:_cleanup_core_files:126 - Deleted intermediate TIFF: C:\BLCA-7_Analysis\temp\Core_000\DAPI.tiff
# 2025-10-17 13:31:27.148 | DEBUG    | multiplex_pipeline.core_cutting.assembler:_cleanup_core_files:126 - Deleted intermediate TIFF: C:\BLCA-7_Analysis\temp\Core_000\HES1.tiff
# 2025-10-17 13:31:27.158 | DEBUG    | multiplex_pipeline.core_cutting.assembler:_cleanup_core_files:126 - Deleted intermediate TIFF: C:\BLCA-7_Analysis\temp\Core_000\HLA1.tiff
# 2025-10-17 13:31:27.169 | DEBUG    | multiplex_pipeline.core_cutting.assembler:_cleanup_core_files:126 - Deleted intermediate TIFF: C:\BLCA-7_Analysis\temp\Core_000\NaKATPase.tiff
# 2025-10-17 13:31:27.178 | DEBUG    | multiplex_pipeline.core_cutting.assembler:_cleanup_core_files:126 - Deleted intermediate TIFF: C:\BLCA-7_Analysis\temp\Core_000\pCK26.tiff
# 2025-10-17 13:31:27.187 | DEBUG    | multiplex_pipeline.core_cutting.assembler:_cleanup_core_files:126 - Deleted intermediate TIFF: C:\BLCA-7_Analysis\temp\Core_000\pS6.tiff
# 2025-10-17 13:31:27.188 | INFO     | multiplex_pipeline.core_cutting.controller:run:136 - All channels processed and cores assembled.
